# %% [markdown]
# <a href="https://colab.research.google.com/github/lethingoctham/bt-list/blob/main/ngoctham_bs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 Tải 1 url về

# %%
from bs4 import BeautifulSoup
import requests
import os
from urllib.request import urlopen

# %%
url = "https://vtv.vn/truyen-hinh-truc-tuyen/vtv1.htm"
page = requests.get(url)
soup = BeautifulSoup(page.text, "html.parser")
html = soup.prettify()
#print(html)

# %% [markdown]
# 2. Lưu 1 html vào thư mục chỉ định

# %%
file = 'url_list' + '.txt'
f = open(file, mode = 'w')
f.write('url\n')    #nội dung file
f.close()
x = 'C:\\Users\\ADMIN\\Desktop'+'\\'+file

os.rename(file,x)   #lưu file

# %% [markdown]
# 3. Cách lấy 1 phần tử đầu tiên ra khỏi list và xóa nó khỏi list

# %%
m = ['hoa','huệ','mai','hồng']
print('CHuỗi trước khi edit:',m)
x = m.pop(0)
print('Phần tử đầu tiên:',x)
print('Chuỗi sau khi edit:',m)
# Out:
# CHuỗi trước khi edit: ['hoa', 'huệ', 'mai', 'hồng']
# Phần tử đầu tiên: hoa
# Chuỗi sau khi edit: ['huệ', 'mai', 'hồng']

# %% [markdown]
# 4. Cách lấy các url trong html

# %%
html = urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
tt = bs.find_all("a")
#print(len(ts))
for item in tt :
   link = item.get("href")
   #print(link)
   url_list.append(link)
#print(len(url_list))
for item in url_list:
    item = str(item)
    if (item.find("http", 0, 4)):
        if (item.find("java", 0, 4)):
            print(item)        
    if not(item.find("http", 0, 4)):
        print(item)
# Out:
# /
# /truyen-hinh-truc-tuyen.htm
# /truyen-hinh-truc-tuyen.htm
# /truyen-hinh-truc-tuyen/vtv1.htm
# /truyen-hinh-truc-tuyen/vtv2.htm
# /truyen-hinh-truc-tuyen/vtv3.htm
# /truyen-hinh-truc-tuyen/vtv4.htm
# /truyen-hinh-truc-tuyen/vtv5.htm
# /truyen-hinh-truc-tuyen/vtv5-tay-nam-bo.htm
# /truyen-hinh-truc-tuyen/vtv5-tay-nguyen.htm
# /vtv6/truyen-hinh-truc-tuyen.htm
# /truyen-hinh-truc-tuyen/vtv7.htm
# /vtv8/truyen-hinh-truc-tuyen.htm
# /truyen-hinh-truc-tuyen/vtv9.htm
# /lich-phat-song.htm
# /video/trai-dat-xanh-12-01-2021-480802.htm
# /video/trai-dat-xanh-12-01-2021-480802.htm
# /truyen-hinh-truc-tuyen/vtv1/trai-dat-xanh-0.htm
# /video/tai-chinh-kinh-doanh-trua-12-01-2021-480798.htm
# /video/tai-chinh-kinh-doanh-trua-12-01-2021-480798.htm
# /truyen-hinh-truc-tuyen/vtv1/kinh-te-0.htm
# /video/5-phut-hom-nay-12-01-2021-480796.htm
# /video/5-phut-hom-nay-12-01-2021-480796.htm
# /truyen-hinh-truc-tuyen/vtv1/5-phut-hom-nay-0.htm
# ...

# %%
# Out:
# 336
# /
# /truyen-hinh-truc-tuyen.htm
# /truyen-hinh-truc-tuyen.htm
# /truyen-hinh-truc-tuyen/vtv1.htm
# /truyen-hinh-truc-tuyen/vtv2.htm
# /truyen-hinh-truc-tuyen/vtv3.htm
# /truyen-hinh-truc-tuyen/vtv4.htm
# /truyen-hinh-truc-tuyen/vtv5.htm
# /truyen-hinh-truc-tuyen/vtv5-tay-nam-bo.htm
# /truyen-hinh-truc-tuyen/vtv5-tay-nguyen.htm
# /vtv6/truyen-hinh-truc-tuyen.htm
# /truyen-hinh-truc-tuyen/vtv7.htm
# /vtv8/truyen-hinh-truc-tuyen.htm
# /truyen-hinh-truc-tuyen/vtv9.htm
# /lich-phat-song.htm
# /video/trai-dat-xanh-12-01-2021-480802.htm
# /video/trai-dat-xanh-12-01-2021-480802.htm
# /truyen-hinh-truc-tuyen/vtv1/trai-dat-xanh-0.htm
# /video/tai-chinh-kinh-doanh-trua-12-01-2021-480798.htm
# /video/tai-chinh-kinh-doanh-trua-12-01-2021-480798.htm
# /truyen-hinh-truc-tuyen/vtv1/kinh-te-0.htm
# /video/5-phut-hom-nay-12-01-2021-480796.htm
# /video/5-phut-hom-nay-12-01-2021-480796.htm
# /truyen-hinh-truc-tuyen/vtv1/5-phut-hom-nay-0.htm
# ...

# %% [markdown]
# 5.Kiểm tra đường link
